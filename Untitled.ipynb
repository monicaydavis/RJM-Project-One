# %%
import yfinance as yf

# %%
data = yf.download(
    "MRNA GOLD ETH-USD XOM DLR BTC-USD NKE OSTK",
    start="2019-01-01", 
    end="2023-06-30"
)
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
data.head
# Out:
# <bound method NDFrame.head of                Adj Close                                                  \
#                  BTC-USD         DLR      ETH-USD       GOLD        MRNA
# Date
# 2019-01-01   3843.520020         NaN   140.819412        NaN         NaN
# 2019-01-02   3943.409424   87.750114   155.047684  11.761898   15.330000
# 2019-01-03   3836.741211   87.307892   149.135010  11.672113   15.500000
# 2019-01-04   3857.717529   89.127693   154.581940  11.752922   16.959999
# 2019-01-05   3845.194580         NaN   155.638596        NaN         NaN
# ...                  ...         ...          ...        ...         ...
# 2023-06-25  30480.261719         NaN  1900.506104        NaN         NaN
# 2023-06-26  30271.130859  107.199997  1859.432861  16.570000  120.410004
# 2023-06-27  30688.164062  109.019997  1889.703369  16.660000  120.669998
# 2023-06-28  30086.246094  109.589996  1827.971191  16.600000  123.000000
# ...

# %%
yf.download(tickers = "MRNA GOLD ETH-USD XOM DLR BTC-USD NKE OSTK",  # list of tickers
            period = "4y",         # time period
            interval = "1d",       # trading interval
            prepost = False,       # download pre/post market hours data?
            repair = True)         # repair obvious price errors e.g. 100x?
# Out:
# [*********************100%***********************]  8 of 8 completed
#                Adj Close                                                  \
#                  BTC-USD         DLR      ETH-USD       GOLD        MRNA
# Date
# 2019-07-10  12156.512695         NaN   290.002319        NaN         NaN
# 2019-07-11  11358.662109  104.836601   268.704041  14.766109   14.440000
# 2019-07-12  11815.986328  104.005035   276.276703  14.874221   14.200000
# 2019-07-13  11392.378906         NaN   269.458801        NaN         NaN
# 2019-07-14  10256.058594         NaN   227.578064        NaN         NaN
# ...                  ...         ...          ...        ...         ...
# 2023-07-06  29909.337891  114.489998  1848.636475  16.219999  118.290001
# 2023-07-07  30342.265625  113.800003  1870.602539  16.340000  118.870003
# 2023-07-08  30292.541016         NaN  1865.539551        NaN         NaN
# 2023-07-09  30171.234375         NaN  1863.009766        NaN         NaN
# ...

# %%
data = yf.download(tickers = "MRNA GOLD ETH-USD XOM DLR BTC-USD NKE OSTK",  # list of tickers
            period = "4y",         # time period
            interval = "1d",       # trading interval
            prepost = False,       # download pre/post market hours data?
            repair = True)         # repair obvious price errors e.g. 100x?
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
data
# Out:
#                Adj Close                                                  \
#                  BTC-USD         DLR      ETH-USD       GOLD        MRNA
# Date
# 2019-07-10  12156.512695         NaN   290.002319        NaN         NaN
# 2019-07-11  11358.662109  104.836609   268.704041  14.766108   14.440000
# 2019-07-12  11815.986328  104.005035   276.276703  14.874222   14.200000
# 2019-07-13  11392.378906         NaN   269.458801        NaN         NaN
# 2019-07-14  10256.058594         NaN   227.578064        NaN         NaN
# ...                  ...         ...          ...        ...         ...
# 2023-07-06  29909.337891  114.489998  1848.636475  16.219999  118.290001
# 2023-07-07  30342.265625  113.800003  1870.602539  16.340000  118.870003
# 2023-07-08  30292.541016         NaN  1865.539551        NaN         NaN
# 2023-07-09  30171.234375         NaN  1863.009766        NaN         NaN
# 2023-07-10  30375.546875  114.010002  1879.686279  16.530001  123.089996
#
# ...

# %%
data = data.drop(columns=['Adj Close', 'High', 'Low'])

# %%
data.columns
# Out:
# MultiIndex([(    'Close', 'BTC-USD'),
#             (    'Close',     'DLR'),
#             (    'Close', 'ETH-USD'),
#             (    'Close',    'GOLD'),
#             (    'Close',    'MRNA'),
#             (    'Close',     'NKE'),
#             (    'Close',    'OSTK'),
#             (    'Close',     'XOM'),
#             (     'High', 'BTC-USD'),
#             (     'High',     'DLR'),
#             (     'High', 'ETH-USD'),
#             (     'High',    'GOLD'),
#             (     'High',    'MRNA'),
#             (     'High',     'NKE'),
#             (     'High',    'OSTK'),
#             (     'High',     'XOM'),
#             (      'Low', 'BTC-USD'),
#             (      'Low',     'DLR'),
#             (      'Low', 'ETH-USD'),
#             (      'Low',    'GOLD'),
#             (      'Low',    'MRNA'),
#             (      'Low',     'NKE'),
#             (      'Low',    'OSTK'),
#             (      'Low',     'XOM'),
#             (     'Open', 'BTC-USD'),
# ...
